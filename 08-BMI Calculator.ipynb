# %% [markdown]
# # BMI Calculator
#
# https://www.calculator.net/bmi-calculator.html

# %%
Name= input("Enter your name:")
Weight= int(input("Enter your weight in pounds: "))

Height= int(input("Enter your height in inches: "))

BMI = (Weight * 703) / (Height * Height)
print(BMI)
if BMI>0 :
    if BMI<16:
        print(Name + ", you have Severe Thinness")
    elif BMI <17:
        print(Name + ", you have Moderate Thickness")
    elif BMI<18.5:
        print(Name + ", you have Mild Thickness")
    elif BMI<25:
        print(Name + ", you are Normal")
    elif BMI<30:
        print(Name + ", you are Overweight")
    elif BMI<35:
        print(Name + ", you have Obese Class I")
    elif BMI<40:
        print(Name + ", you have Obese Class II")
else: 
        print(Name + ", you have Obese Class III")
# Out:
# Enter your name: fhg
# Enter your weight in pounds:  165
# Enter your height in inches:  64
# 28.319091796875
# fhg, you are Overweight

# %%
Severe Thinness	< 16	
Moderate Thinness	16 - 17	
Mild Thinness	17 - 18.5	
Normal	18.5 - 25	
Overweight	25 - 30	
Obese Class I	30 - 35
Obese Class II	35 - 40
Obese Class III	> 40

# %%
if BMI>0 :
    if BMI<16:
        print(Name + ", you have Severe Thinkness")
    elif BMI <17:
        print(Name + ", you have Moderate Thickness")
    elif BMI<18.5:
        print(Name + ", you have Mild Thickness")
    elif BMI<25:
        print(Name + ", you have Normal")
    elif BMI<30:
        print(Name + ", you have Overweight")
    elif BMI<35:
        print(Name + ", you have Obese Class I")
    elif BMI<40:
        print(Name + ", you have Obese Class II")
else:
    print(Name + ", you have Obese Class III")
# Out:
# fhg, you have Overweight

# %%
#BMI = (wieght in pounds * 703) / (height in inches * height in inches)
