# %% [markdown]
# ## Comparison Operators

# %%
10 == 10
# Out:
# True

# %%
10 != 50
# Out:
# True

# %%
x ='Vanilla'
y='Chcolate'
x!=y
# Out:
# True

# %%
10<50
# Out:
# True

# %%
10>50
# Out:
# False

# %%
10>=10
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %%
(10>50) and (40>10)  # for True Both should be True
# Out:
# False

# %%
(70>50) and (40>10)
# Out:
# True

# %%
('Vanilla' > 'Chocolate') and (40>10)   # V has greater value Than C(3rd position)
# Out:
# True

# %%
(10>50) or (40>10)
# Out:
# True

# %%
not(50>10)
# Out:
# False

# %% [markdown]
# ## Membership Operators

# %%
ice_cream = "I love Chocolate Ice cream"
"love" in ice_cream
# Out:
# True

# %%
ice_cream = "I love Chocolate Ice cream"
"Vanilla" in ice_cream
# Out:
# False

# %%
ice_cream = "I love Chocolate Ice cream"
"love" not in ice_cream
# Out:
# False

# %%
scoops=[1,2,3,4,5]
6 not in scoops
# Out:
# True

# %%
scoops=[1,2,3,4,5]
wanted=[8]
wanted in scoops
# Out:
# False
