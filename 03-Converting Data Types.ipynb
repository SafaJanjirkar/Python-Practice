# %% [markdown]
# ## Converting Data Types

# %%
num_int = 7
type(num_int)
# Out:
# int

# %%
num_str ='7'
type(num_str)
# Out:
# str

# %%
num_sum = num_int + num_str    # it will give error so 1sst we have to convert data types
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 num_sum = num_int + num_str
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num_str_conv = int(num_str)

# %%
type(num_str_conv)
# Out:
# int

# %%
num_sum = num_int + num_str_conv
print(num_sum)
# Out:
# 14

# %% [markdown]
# #### Lists into Tuple

# %%
num_list=[2,3,6]
type(num_list)
# Out:
# list

# %%
tuple(num_list)
# Out:
# (2, 3, 6)

# %%
type(tuple(num_list))
# Out:
# tuple

# %%
num_lists2=[1,2,3,1,2,2,1,3]

# %%
set(num_lists2)
# Out:
# {1, 2, 3}

# %%
type(set(num_lists2))
# Out:
# set

# %% [markdown]
# ### Dict to list

# %%
num_dict={'name': 'Safa' , 'Age' :22 , 'gender' : 'female'}

# %%
type(num_dict)
# Out:
# dict

# %%
num_dict.items()
# Out:
# dict_items([('name', 'Safa'), ('Age', 22), ('gender', 'female')])

# %%
num_dict.values()
# Out:
# dict_values(['Safa', 22, 'female'])

# %%
num_dict.keys()
# Out:
# dict_keys(['name', 'Age', 'gender'])

# %%
list(num_dict.keys())
# Out:
# ['name', 'Age', 'gender']

# %%
type(list(num_dict.keys()))
# Out:
# list

# %%
type(list(num_dict.values()))
# Out:
# list

# %%
long_str="I lik
