# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # First Notebook

# %% [markdown]
# ## Variables

# %%
x = 22
print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y="SS"
print(y)
type(y)
# Out:
# SS
# str

# %%
# Variables are case sensitive 
a ="Safa"
A = "girl"
print(A)
# Out:
# girl

# %%
x,y,z = "Chocolate" , "Chips" , "Icecream"

# %%
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Chips
# Icecream

# %%
x = y = z = "Safa Abc XYZ"
print(x)
print(y)
print(z)
# Out:
# Safa Abc XYZ
# Safa Abc XYZ
# Safa Abc XYZ

# %%
ice_cream= ["Chocolate" , "Chips" , "Icecream"]
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Chips
# Icecream

# %%
# Camel Case

#Test Variable Case

testVariableCase= 'Vanilla Swirl'

# %%
# Pascal Case

#Test Variable Case

TestVariableCase= 'Vanilla Swirl'

# %%
# Snake Case

#Test Variable Case

test_variable_case= 'Vanilla Swirl'

# %%
testvar= 'SAFA'
test_var='Safa'
_test_var='Safa'
TestVar='Safa'
testvar2='safa'

# %%
# We cant use variable like this

2testvar='Safa'
test-var='Safa'
test var2 ='Safa'
test,var2='Safa'

# %%
x ='Ice Cream is may Fav' + ' and also chocolate' + '.'
print(x)
# Out:
# Ice Cream is may Fav and also chocolate.

# %%
# This will give error because we cant concatenate string to integer
y ='Ice Cream is may Fav' + 2
print(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # NO
# ----> 2 y ='Ice Cream is may Fav' + 2
#       3 print(y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a =2+3
print(a)
# Out:
# 5

# %%
x='Ice cream'
y=' is'
z=' my fav.'
print(x+y+z)
# Out:
# Ice cream is my fav.

# %%
x= 2
y= 3
z=1
print(x+y+z)
# Out:
# 6

# %%
x ='Ice cream'
y =2
print(x,y)
# Out:
# Ice cream 2
